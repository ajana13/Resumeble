# %%
from pdfminer.converter import TextConverter
from pdfminer.pdfinterp import PDFPageInterpreter
from pdfminer.pdfinterp import PDFResourceManager
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
import spacy 
from spacy.matcher import Matcher
import re
import pandas as pd
from nltk.corpus import stopwords
import os
import io
import nltk
import docx2txt

# %%
def extract_text_from_pdf(pdf_path):
    with open(pdf_path, 'rb') as fh:
        # iterate over all pages of PDF document
        for page in PDFPage.get_pages(fh, caching=True, check_extractable=True):
            # creating a resoure manager
            resource_manager = PDFResourceManager()
            
            # create a file handle
            fake_file_handle = io.StringIO()
            
            # creating a text converter object
            converter = TextConverter(
                                resource_manager, 
                                fake_file_handle, 
                                codec='utf-8', 
                                laparams=LAParams()
                        )

            # creating a page interpreter
            page_interpreter = PDFPageInterpreter(
                                resource_manager, 
                                converter
                            )

            # process current page
            page_interpreter.process_page(page)
            
            # extract text
            text = fake_file_handle.getvalue()
            yield text

            # close open handles
            converter.close()
            fake_file_handle.close()

def text_from_doc(doc_path):
    '''
    Helper function to extract plain text from .doc or .docx files
    :param doc_path: path to .doc or .docx file to be extracted
    :return: string of extracted text
    '''
    temp = docx2txt.process(doc_path)
    text = [line.replace('\t', ' ') for line in temp.split('\n') if line]
    return ' '.join(text)

# %%
def extract_text(file_path, extension):
    '''
    Wrapper function to detect the file extension and call text extraction function accordingly
    :param file_path: path of file of which text is to be extracted
    :param extension: extension of file `file_name`
    '''
    text = ''
    if extension == '.pdf':
        for page in extract_text_from_pdf(file_path):
            text += ' ' + page
    elif extension == '.docx' or extension == '.doc':
        text = text_from_doc(file_path)
    return text

# %%
def extract_education(nlp_text):
    '''
    Helper function to extract education from spacy nlp text
    :param nlp_text: object of `spacy.tokens.doc.Doc`
    :return: tuple of education degree and year if year if found else only returns education degree
    '''
    # load pre-trained model
    nlp = spacy.load('en_core_web_sm')

    # Grad all general stop words
    STOPWORDS = set(stopwords.words('english'))

    # Education Degrees
    EDUCATION = [
                'BE','B.E.', 'B.E', 'BS', 'B.S', 'B.S.', 
                'ME', 'M.E', 'M.E.', 'MS', 'M.S', 
                'BTECH', 'B.TECH', 'M.TECH', 'MTECH', 
                'SSC', 'HSC', 'CBSE', 'ICSE', 'X', 'XII', 'BACHELOR OF SCIENCE'
            ]
    edu = {}
    # Extract education degree
    for index, tex in enumerate(nlp_text.splitlines()):
        # print(tex)
        tex = re.sub(r'[?|$|.|!|,]', r'', tex)
        #print(tex)
        if tex.upper() in EDUCATION:
            edu[tex] = text + nlp_text[index + 1]
        #if tex.upper() in EDUCATION and tex not in STOPWORDS:
        #    edu[tex] = text + nlp_text[index + 1]
    # print(edu)
    # Extract year
    education = []
    for key in edu.keys():
        year = re.search(re.compile(r'(((20|19)(\d{2})))'), edu[key])
        if year:
            education.append((key, ''.join(year.group(0))))
        else:
            education.append(key)
    return education

# %%
def extract_university(text):
    df = pd.read_csv('world-universities.csv', header=None)
    universities = set([i.lower() for i in df[1]])
    college_name = []
    listex = universities
    listsearch = text.lower().splitlines()

    # print(listsearch)
    print(len(listsearch))
    print(len(universities))
    for i in range(len(listex)):
        for ii in range(len(listsearch)):
            #print(listsearch[ii])
            if re.findall(listex[i], re.sub(' +', ' ', listsearch[ii])):
                college_name.append(listex[i])
    return college_name

# %%
resume = "TimothyNguyen2022.pdf"
resume_text = extract_text(resume, os.path.splitext(resume)[1])
# print(resume_text)

# %%
extract_education(resume_text)
# Out:
# []

# %%
extract_university(resume_text)
# Out:
# 86
# {'art institute of charlotte', 'kursk state medical university', 'shandong university of triaditional chinese medicine', 'hokkaido university of education', "université notre dame d'haïti", 'chuo gakuin university', 'toyama prefectural university', 'aimst university', 'itt technical institute portland', 'university of british columbia', 'universitas tidar magelang', 'godfrey okoye university', 'institute of teachers education, perlis', 'brenau university', 'zhejiang gongshang university', 'iniciativa universidad del atlantico', 'universidad monsenor oscar arnulfo romeo', 'universidade do oeste de santa catarina', 'palestine technical college-dier elbalah', 'soongsil university', 'university of the gambia', 'claflin college', 'fachhochschule lübeck', 'university of maryland baltimore county', 'cetys universidad', 'kolej universiti insaniah', 'universidad de puerto rico, ponce', 'brescia college', 'ukhta state technical university', 'dayalbagh educational institute', 'indian institute of technology, madras', 'riyadh college of dentistry and pharmacy', 'rasmussen college', 'tiffin university prague', 'l.n. gumilyov eurasian national university', ' université de nouakchott', 'katholische fachhochschule norddeutschland', 'universidad de comunicación avanzada', 'sardar vallabhai patel university of agriculture amd technology', 'université kongo', 'holy family college', 'gondar university', 'communication university of china', 'universidad del tolima', 'baghdad college of economic sciences university', 'western baptist college', 'okayama shoka university', 'minsk institute of management', 'ohio state university - marion', 'kyoto gakuen university', 'suffolk university', 'universidad de montevideo', 'virginia state university', 'institute of science and technology', 'southwest university of finance and economics', 'universidad internacional de andalucía', 'curtin university of technology', 'alderson broaddus college', 'kyushu kyoritsu university', 'aljouf university', 'st. petersburg state institute of technology (technological university)', 'northern kentucky university', 'university "transilvany" of brasov', "université d'artois", 'rajiv gandhi university', 'tarlac state university', 'zhongnan university of technology', 'university of pula', 'technological education institute of serres', 'hawler medical university', 'hankuk aviation university', 'daido institute of technology', 'national taiwan college of physical education and sports', 'city university of new york, city college', 'universitas islam sultan agung', 'osmangazi university', 'universidade federal da grande dourados', 'himachal pradesh agricultural university', 'saint ferdinand college', 'california maritime academy', 'universidad del noreste', 'iowa wesleyan college', 'institut teknologi sepuluh nopember', 'university of science and culture', 'universidad simón bolivar', 'hamdard university', 'business and hotel management school', "koka women's college", 'american world university', 'savannah college of art and design', 'university of hong kong', 'avila college', 'wesley college', 'universidad de puerto rico, cayey', 'pedagogical university of zielona gora', 'mekelle institute of technology', "chubu gakuin university & chubu women's college", 'pannnasatra university of cambodia', 'university of iowa', 'stockholm school of economics', 'lakshmibai national institute of physical education', 'indiana university - northwest', 'university of south carolina - salkehatchie', 'hochschule zittau/görlitz (fh)', 'lviv national university ivan franko', 'islamic azad university, tehran science & research branch', 'universidad experimental felix adam', 'majmaah university', 'nara university of education', 'vancouver community college', 'al maarif university college', 'universidad privada san juan bautista', 'universitas sanata dharma', 'technical university of zielona gora', 'national institute of technology, jamshedpur', 'holy spirit university of kaslik', 'universidad nacional de a ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-3743ee7f5b6f> in <module>
# ----> 1 extract_university(resume_text)
#
# <ipython-input-72-e4676bb8e057> in extract_university(text)
#      12         for ii in range(len(listsearch)):
#      13             #print(listsearch[ii])
# ---> 14             if re.findall(listex[i], re.sub(' +', ' ', listsearch[ii])):
#      15                 college_name.append(listex[i])
#      16     return college_name
#
# TypeError: 'set' object is not subscriptable
